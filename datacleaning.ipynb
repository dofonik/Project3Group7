# %%
# Import dependencies
import pandas as pd
import numpy as np

world_data_df = pd.read_excel('resources/world-data-2023.xlsx')
world_data_df.head()
# Out:
#   country_name  Density\n(P/Km2) Abbreviation  Agricultural Land( %)  \
# 0  Afghanistan                60           AF                  0.581
# 1      Albania               105           AL                  0.431
# 2      Algeria                18           DZ                  0.174
# 3      Andorra               164           AD                  0.400
# 4       Angola                26           AO                  0.475
#
#    Land Area(Km2)  Armed Forces size  Birth Rate  Calling Code  \
# 0        652230.0           323000.0       32.49          93.0
# 1         28748.0             9000.0       11.78         355.0
# 2       2381741.0           317000.0       24.28         213.0
# 3           468.0                NaN        7.20         376.0
# 4       1246700.0           117000.0       40.73         244.0
#
#   Capital/Major City  Co2-Emissions  ...  Physicians per thousand  Population  \
# 0              Kabul         8672.0  ...                     0.28  38041754.0
# ...

# %%
# columns we want to keep
world_data_clean = ["country_name","Density\n(P/Km2)","Birth Rate","Co2-Emissions","CPI Change (%)","Fertility Rate", "GDP","Infant mortality","Life expectancy","Maternal mortality ratio","Minimum wage","Out of pocket health expenditure","Physicians per thousand","Population","Tax revenue (%)","Total tax rate","Unemployment rate","Urban_population","Latitude","Longitude"]
df_worldclean_data = world_data_df[world_data_clean]
df_worldclean_data.head()
# Out:
#   country_name  Density\n(P/Km2)  Birth Rate  Co2-Emissions  CPI Change (%)  \
# 0  Afghanistan                60       32.49         8672.0           0.023
# 1      Albania               105       11.78         4536.0           0.014
# 2      Algeria                18       24.28       150006.0           0.020
# 3      Andorra               164        7.20          469.0             NaN
# 4       Angola                26       40.73        34693.0           0.171
#
#    Fertility Rate           GDP  Infant mortality  Life expectancy  \
# 0            4.47  1.910135e+10              47.9             64.5
# 1            1.62  1.527808e+10               7.8             78.5
# 2            3.02  1.699882e+11              20.1             76.7
# 3            1.27  3.154058e+09               2.7              NaN
# 4            5.52  9.463542e+10              51.6             60.8
#
#    Maternal mortality ratio  Minimum wage  Out of pocket health expenditure  \
# ...

# %%
df_worldclean_data.dtypes
# Out:
# country_name                         object
# Density\n(P/Km2)                      int64
# Birth Rate                          float64
# Co2-Emissions                       float64
# CPI Change (%)                      float64
# Fertility Rate                      float64
# GDP                                 float64
# Infant mortality                    float64
# Life expectancy                     float64
# Maternal mortality ratio            float64
# Minimum wage                        float64
# Out of pocket health expenditure    float64
# Physicians per thousand             float64
# Population                          float64
# Tax revenue (%)                     float64
# Total tax rate                      float64
# Unemployment rate                   float64
# Urban_population                    float64
# Latitude                            float64
# Longitude                           float64
# dtype: object

# %%
df_worldclean_data.to_csv("output/worldcleandata.csv", index=False)

# %%
worldhappiness_data_df = pd.read_excel('resources/world-happiness-report-2021.xlsx')
worldhappiness_data_df.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
# Rename the blurb, launched_at, and deadline columns.
worldhappiness_data_df.rename(columns={'Ladder score': 'Happiness Score',
                                          }, inplace=True)
worldhappiness_data_df.head()
# Out:
#   Country name Regional indicator  Happiness Score  \
# 0      Finland     Western Europe            7.842
# 1      Denmark     Western Europe            7.620
# 2  Switzerland     Western Europe            7.571
# 3      Iceland     Western Europe            7.554
# 4  Netherlands     Western Europe            7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
# columns we want to keep
worldhappiness_clean = ["Country name","Happiness Score","Social support","Freedom to make life choices","Generosity","Perceptions of corruption"]
df_worldhappiness = worldhappiness_data_df[worldhappiness_clean]
df_worldhappiness.head()
# Out:
#   Country name  Happiness Score  Social support  Freedom to make life choices  \
# 0      Finland            7.842           0.954                         0.949
# 1      Denmark            7.620           0.954                         0.946
# 2  Switzerland            7.571           0.942                         0.919
# 3      Iceland            7.554           0.983                         0.955
# 4  Netherlands            7.464           0.942                         0.913
#
#    Generosity  Perceptions of corruption
# 0      -0.098                      0.186
# 1       0.030                      0.179
# 2       0.025                      0.292
# 3       0.160                      0.673
# 4       0.175                      0.338

# %%
df_worldhappiness.dtypes
# Out:
# Country name                     object
# Happiness Score                 float64
# Social support                  float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
df_worldhappiness.to_csv("output/worldhappinesscleandata.csv", index=False)

# %%
pip install dash
# Out:
# ...
#   Obtaining dependency information for dash from https://files.pythonhosted.org/packages/b0/68/781d0026a100106b64e4501c76621dfcd0d3c29a546094fcffaa73037a74/dash-2.16.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for dash-html-components==2.0.0 from https://files.pythonhosted.org/packages/75/65/1b16b853844ef59b2742a7de74a598f376ac0ab581f0dcc34db294e5c90e/dash_html_components-2.0.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for dash-core-components==2.0.0 from https://files.pythonhosted.org/packages/00/9e/a29f726e84e531a36d56cff187e61d8c96d2cc253c5bcef9a7695acb7e6a/dash_core_components-2.0.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for dash-table==5.0.0 from https://files.pythonhosted.org/packages/da/ce/43f77dc8e7bbad02a9f88d07bf794eaf68359df756a28bb9f2f78e255bb1/dash_table-5.0.0-py3-none-any.whl.metadata
# ...
